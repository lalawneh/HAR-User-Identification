# %%
import numpy
import tensorflow
import sklearn.model_selection as sk
from matplotlib import pyplot as plt
import os
import os.path
import glob
import numpy as np
# lstm model
import random
from numpy  import mean
from numpy  import std
from numpy  import dstack
from pandas import read_csv
import pandas as pd
import seaborn as sns
from scipy import stats
from IPython.display import display, HTML
#import keras
import collections
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Dropout
from tensorflow.keras.layers import LSTM
from tensorflow.keras.layers import Bidirectional
from tensorflow.keras.utils  import to_categorical
#from tensorflow.keras.utils import np_utils
from tensorflow.keras.preprocessing.sequence import TimeseriesGenerator
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras import optimizers
from tensorflow.keras.callbacks import History
from sklearn.metrics import mean_squared_error
from datetime import datetime
 
from matplotlib   import pyplot
from sklearn import metrics
from sklearn.metrics import classification_report
from sklearn import preprocessing

#%%%%%%%%%%%%%%%%%%%Initialization information%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%% 
print('Tensorflow version:' , tensorflow.__version__)
# Set some standard parameters upfront
pd.options.display.float_format = '{:.1f}'.format
sns.set() # Default seaborn look and feel
plt.style.use('ggplot')
print('keras version ', tensorflow.keras.__version__)
#%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
def import_data(path):
    files = glob.glob(path +'/*.csv')
    list_of_dfs = {}
    dfs = []
    for i in range(0,len(files)):
        dfs.append(os.path.basename(files[i])[:-4])
    for df, file in zip(dfs, files):        
        list_of_dfs[df] = read_csv(file, header = None)
    print("Loaded data successfully!")
    return list_of_dfs
#NNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNN
def show_confusion_matrix(validations, predictions): 
    matrix = metrics.confusion_matrix(validations, predictions)        
    matrix1 = matrix.astype('float') / matrix.sum(axis=1)[:, np.newaxis]
    print(matrix)
    plt.figure(figsize=(7, 7))
    plt.xticks(fontsize=10)
    plt.yticks(fontsize=10)
    sns.set(font_scale=0.7) # Adjust to fit
    ss = sns.heatmap(matrix1,
                cmap=plt.cm.Blues,
                linecolor='white',
                linewidths=1,
                annot=matrix,
                cbar=False,
                xticklabels=LABELS,
                yticklabels=LABELS,                
                fmt='')    
    figure = ss.get_figure()    
    figure.savefig(path+'unimib-user-identification.eps', dpi=400)
    plt.title('Confusion Matrix')    
    tick_marks = np.arange(n_outputs) + 0.5
    plt.xticks(tick_marks, LABELS, rotation=90)
    plt.yticks(tick_marks, LABELS, rotation=0)
    plt.show()
#NNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNN
class myCallback(tensorflow.keras.callbacks.Callback): 
    def on_epoch_end(self, epoch, logs={}):   
      if(logs.get('val_accuracy') > ACCURACY_THRESHOLD):   
        print("\nReached %2.2f%% accuracy, so stopping training!!" %(ACCURACY_THRESHOLD*100))   
        self.model.stop_training = True
#NNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNN
def build_model(trainX, trainY):
    history = History()
    model = Sequential()    
    model.add(LSTM(lstm_output_units, return_sequences=False, input_shape=(n_timesteps,n_features)))        
    for a in range(hidden_layers):
      model.add(Dropout(dropout))
      model.add(Dense(hidden_units, activation='swish'))   
    model.add(Dense(n_outputs, activation='softmax'))

    callbacks = myCallback()
    optimizer = optimizers.Adam(learning_rate=learning_rate)    
    model.compile(loss='categorical_crossentropy', optimizer=optimizer, metrics=['accuracy'])
    print(model.summary())
    #Fit network    
    history = model.fit(trainX, trainY, epochs=epochs, validation_data=(validationX, validationY), batch_size=batch_size, verbose=verbose, callbacks=[callbacks])
    return model
#%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
def setup_data():
    # load data
    data = import_data(path)

    #Get training data:
    dataX = data[acc_data].values
    dataX = np.reshape(dataX,(dataX.shape[0],n_timesteps, n_features))   
    dataY = data[acc_labels][1].values 
    dataY = np.asarray(pd.get_dummies(dataY), dtype = np.float32)

    trainX, testX, trainY, testY = sk.train_test_split(dataX,dataY,test_size=0.3, shuffle=1, random_state = 1,stratify=dataY)
    testX, validationX, testY, validationY = sk.train_test_split(testX,testY,test_size=0.5, shuffle=1, random_state = 1,stratify=testY)

    return trainX, testX, trainY, testY, validationX, validationY        
#%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
def start_model_training():
        
    model = build_model(trainX, trainY)    
    _, accuracy = model.evaluate(testX, testY, batch_size=batch_size, verbose=verbose)
    score = accuracy * 100.0
    print('Accuracy: %.3f' % (score))
    logfile.write('Accuracy: %.3f\r\n' % (score))
 
    y_pred_test = model.predict(testX)
    #predict test samples (select the class with the highest probability):
    max_y_pred_test = np.argmax(y_pred_test, axis=1)
    max_y_test = np.argmax(testY, axis=1)

    show_confusion_matrix(max_y_test, max_y_pred_test)
    print(classification_report(max_y_test, max_y_pred_test))
    model.save(path+model_name+".h5")
    print("Saved model to disk")
    return model
#%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
LABELS = [ 
    "User 1",
    "User 2",
    "User 3",
    "User 4",
    "User 5",
    "User 6",
    "User 7",
    "User 8",
    "User 9",
    "User 10",
    "User 11",
    "User 12",
    "User 13",
    "User 14",
    "User 15",
    "User 16",
    "User 17",
    "User 18",
    "User 19",
    "User 20",
    "User 21",
    "User 22",
    "User 23",
    "User 24",
    "User 25",
    "User 26",
    "User 27",
    "User 28",
    "User 29",
    "User 30"
    ]
#configure all parameters, files, split, augmentation here:
path = "/content/drive/MyDrive/HAR/unimib/" #folder containing input data
filename = path+"logs/"+datetime.now().strftime("d%d-%m-%Y-t%H-%M-%S.txt")

logfile = open(filename, "w")
logfile.write("Start training the model!\r\n")

n_timesteps, n_features, n_outputs = 151, 3, 30

#hyperparameters:    
lstm_output_units = 500
hidden_layers=1
hidden_units = 500
dropout = 0.5
learning_rate = 0.001
batch_size = 64
epochs = 200
verbose=2
ACCURACY_THRESHOLD = 0.90


print("lstm_output_units: %d hidden_layers: %d hidden_units: %d, dropout: %1.1f learning_rate: %1.5f batch_size: %d epochs: %d" %(lstm_output_units, hidden_layers, hidden_units, dropout, learning_rate, batch_size, epochs))
logfile.write("hidden_layers: %d hidden_units: %d, dropout: %1.1f learning_rate: %1.5f batch_size: %d epochs: %d\r\n" %(hidden_layers, hidden_units, dropout, learning_rate, batch_size, epochs))

acc_data = 'acc_data'      
acc_labels = 'acc_labels'    

trainX, testX, trainY, testY, validationX, validationY = setup_data()

print("trainX.shape, trainY.shape, testX.shape, testY.shape, validationX.shape, validationY.shape")
print(trainX.shape, trainY.shape, testX.shape, testY.shape, validationX.shape, validationY.shape)

model_name = "identification/unimib"
model = start_model_training()
# Out:
# Tensorflow version: 2.8.0
# keras version  2.8.0
# lstm_output_units: 500 hidden_layers: 1 hidden_units: 500, dropout: 0.5 learning_rate: 0.00100 batch_size: 64 epochs: 200
# Loaded data successfully!
# trainX.shape, trainY.shape, testX.shape, testY.shape, validationX.shape, validationY.shape
# (8239, 151, 3) (8239, 30) (1766, 151, 3) (1766, 30) (1766, 151, 3) (1766, 30)
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 500)               1008000
#
#  dropout (Dropout)           (None, 500)               0
#
#  dense (Dense)               (None, 500)               250500
#
#  dense_1 (Dense)             (None, 30)                15030
#
# =================================================================
# Total params: 1,273,530
# Trainable params: 1,273,530
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/200
# 129/129 - 275s - loss: 3.1239 - accuracy: 0.0998 - val_loss: 3.1195 - val_accuracy: 0.1048 - 275s/epoch - 2s/step
# Epoch 2/200
# 129/129 - 267s - loss: 2.8298 - accuracy: 0.1507 - val_loss: 2.6139 - val_accuracy: 0.1812 - 267s/epoch - 2s/step
# Epoch 3/200
# 129/129 - 268s - loss: 2.5349 - accuracy: 0.2139 - val_loss: 2.3998 - val_accuracy: 0.2514 - 268s/epoch - 2s/step
# Epoch 4/200
# 129/129 - 270s - loss: 2.3326 - accuracy: 0.2652 - val_loss: 2.2527 - val_accuracy: 0.2922 - 270s/epoch - 2s/step
# Epoch 5/200
# 129/129 - 271s - loss: 2.1260 - accuracy: 0.3275 - val_loss: 2.0545 - val_accuracy: 0.3545 - 271s/epoch - 2s/step
# Epoch 6/200
# 129/129 - 272s - loss: 1.9009 - accuracy: 0.3940 - val_loss: 1.7906 - val_accuracy: 0.4451 - 272s/epoch - 2s/step
# Epoch 7/200
# 129/129 - 271s - loss: 1.7471 - accuracy: 0.4405 - val_loss: 1.6479 - val_accuracy: 0.4841 - 271s/epoch - 2s/step
# Epoch 8/200
# 129/129 - 272s - loss: 1.5751 - accuracy: 0.4857 - val_loss: 1.5325 - val_accuracy: 0.5260 - 272s/epoch - 2s/step
# Epoch 9/200
# 129/129 - 271s - loss: 1.4083 - accuracy: 0.5448 - val_loss: 1.3359 - val_accuracy: 0.5776 - 271s/epoch - 2s/step
# Epoch 10/200
# 129/129 - 274s - loss: 1.2741 - accuracy: 0.5881 - val_loss: 1.3038 - val_accuracy: 0.5906 - 274s/epoch - 2s/step
# Epoch 11/200
# 129/129 - 273s - loss: 1.1773 - accuracy: 0.6171 - val_loss: 1.2493 - val_accuracy: 0.6082 - 273s/epoch - 2s/step
# Epoch 12/200
# 129/129 - 272s - loss: 1.0493 - accuracy: 0.6625 - val_loss: 1.0845 - val_accuracy: 0.6636 - 272s/epoch - 2s/step
# Epoch 13/200
# 129/129 - 273s - loss: 0.9416 - accuracy: 0.6913 - val_loss: 1.0304 - val_accuracy: 0.6897 - 273s/epoch - 2s/step
# Epoch 14/200
# 129/129 - 271s - loss: 0.8347 - accuracy: 0.7287 - val_loss: 1.0145 - val_accuracy: 0.6874 - 271s/epoch - 2s/step
# Epoch 15/200
# 129/129 - 273s - loss: 0.7744 - accuracy: 0.7526 - val_loss: 1.0421 - val_accuracy: 0.6891 - 273s/epoch - 2s/step
# Epoch 16/200
# 129/129 - 274s - loss: 0.6920 - accuracy: 0.7741 - val_loss: 0.9600 - val_accuracy: 0.7180 - 274s/epoch - 2s/step
# Epoch 17/200
# 129/129 - 287s - loss: 0.6540 - accuracy: 0.7891 - val_loss: 0.8786 - val_accuracy: 0.7525 - 287s/epoch - 2s/step
# Epoch 18/200
# 129/129 - 283s - loss: 0.5837 - accuracy: 0.8126 - val_loss: 0.8293 - val_accuracy: 0.7707 - 283s/epoch - 2s/step
# Epoch 19/200
# 129/129 - 287s - loss: 0.5411 - accuracy: 0.8199 - val_loss: 0.7785 - val_accuracy: 0.7741 - 287s/epoch - 2s/step
# Epoch 20/200
# 129/129 - 280s - loss: 0.4555 - accuracy: 0.8545 - val_loss: 0.7814 - val_accuracy: 0.7729 - 280s/epoch - 2s/step
# Epoch 21/200
# 129/129 - 270s - loss: 0.4482 - accuracy: 0.8533 - val_loss: 0.7716 - val_accuracy: 0.7950 - 270s/epoch - 2s/step
# Epoch 22/200
# 129/129 - 270s - loss: 0.3647 - accuracy: 0.8781 - val_loss: 0.6731 - val_accuracy: 0.8148 - 270s/epoch - 2s/step
# Epoch 23/200
# 129/129 - 270s - loss: 0.3410 - accuracy: 0.8888 - val_loss: 0.7308 - val_accuracy: 0.8063 - 270s/epoch - 2s/step
# Epoch 24/200
# 129/129 - 272s - loss: 0.3507 - accuracy: 0.8829 - val_loss: 0.7355 - val_accuracy: 0.8001 - 272s/epoch - 2s/step
# Epoch 25/200
# 129/129 - 271s - loss: 0.3241 - accuracy: 0.8972 - val_loss: 0.6978 - val_accuracy: 0.8041 - 271s/epoch - 2s/step
# Epoch 26/200
# 129/129 - 272s - loss: 0.3217 - accuracy: 0.8987 - val_loss: 0.7181 - val_accuracy: 0.8148 - 272s/epoch - 2s/step
# Epoch 27/200
# 129/129 - 270s - loss: 0.2917 - accuracy: 0.9046 - val_loss: 0.7226 - val_accuracy: 0.8103 - 270s/epoch - 2s/step
# Epoch 28/200
# 129/129 - 273s - loss: 0.2428 - accuracy: 0.9209 - val_loss: 0.6856 - val_accuracy: 0.8381 - 273s/epoch - 2s/step
# Epoch 29/200
# 129/129 - 272s - loss: 0.2746 - accuracy: 0.9115 - val_loss: 0.7547 - val_accuracy: 0.8211 - 272s/epoch - 2s/step
# Epoch 30/200
# 129/129 - 271s - loss: 0.2664 - accuracy: 0.9153 - val_loss: 0.7092 - val_accuracy: 0.8239 - 271s/epoch - 2s/step
# Epoch 31/200
# 129/129 - 270s - loss: 0.2211 - accuracy: 0.9285 - val_loss: 0.7007 - val_accuracy: 0.8347 - 270s/epoch - 2s/step
# Epoch 32/200
# 129/129 - 268s - loss: 0.2132 - accuracy: 0.9302 - val_loss: 0.7096 - val_accuracy: 0.8307 - 268s/epoch - 2s/step
# Epoch 33/200
# 129/129 - 272s - loss: 0.1798 - accuracy: 0.9398 - val_loss: 0.7061 - val_accuracy: 0.8420 - 272s/epoch - 2s/step
# Epoch 34/200
# 129/129 - 273s - loss: 0.1777 - accuracy: 0.9439 - val_loss: 0.6710 - val_accuracy: 0.8426 - 273s/epoch - 2s/step
# Epoch 35/200
# 129/129 - 272s - loss: 0.1744 - accuracy: 0.9431 - val_loss: 0.7645 - val_accuracy: 0.8335 - 272s/epoch - 2s/step
# Epoch 36/200
# 129/129 - 274s - loss: 0.1688 - accuracy: 0.9465 - val_loss: 0.6812 - val_accuracy: 0.8528 - 274s/epoch - 2s/step
# Epoch 37/200
# 129/129 - 274s - loss: 0.1442 - accuracy: 0.9529 - val_loss: 0.6730 - val_accuracy: 0.8652 - 274s/epoch - 2s/step
# Epoch 38/200
# 129/129 - 272s - loss: 0.1897 - accuracy: 0.9423 - val_loss: 0.7317 - val_accuracy: 0.8335 - 272s/epoch - 2s/step
# Epoch 39/200
# 129/129 - 273s - loss: 0.1834 - accuracy: 0.9460 - val_loss: 0.7257 - val_accuracy: 0.8448 - 273s/epoch - 2s/step
# Epoch 40/200
# 129/129 - 274s - loss: 0.1794 - accuracy: 0.9444 - val_loss: 0.7038 - val_accuracy: 0.8511 - 274s/epoch - 2s/step
# Epoch 41/200
# 129/129 - 275s - loss: 0.1811 - accuracy: 0.9428 - val_loss: 0.6901 - val_accuracy: 0.8528 - 275s/epoch - 2s/step
# Epoch 42/200
# 129/129 - 272s - loss: 0.1339 - accuracy: 0.9564 - val_loss: 0.7145 - val_accuracy: 0.8499 - 272s/epoch - 2s/step
# Epoch 43/200
# 129/129 - 273s - loss: 0.1506 - accuracy: 0.9538 - val_loss: 0.6780 - val_accuracy: 0.8692 - 273s/epoch - 2s/step
# Epoch 44/200
# 129/129 - 273s - loss: 0.1284 - accuracy: 0.9599 - val_loss: 0.7102 - val_accuracy: 0.8579 - 273s/epoch - 2s/step
# Epoch 45/200
# 129/129 - 272s - loss: 0.1144 - accuracy: 0.9648 - val_loss: 0.7032 - val_accuracy: 0.8664 - 272s/epoch - 2s/step
# Epoch 46/200
# 129/129 - 273s - loss: 0.1543 - accuracy: 0.9557 - val_loss: 0.6942 - val_accuracy: 0.8607 - 273s/epoch - 2s/step
# Epoch 47/200
# 129/129 - 274s - loss: 0.1468 - accuracy: 0.9592 - val_loss: 0.7975 - val_accuracy: 0.8420 - 274s/epoch - 2s/step
# Epoch 48/200
# 129/129 - 272s - loss: 0.1873 - accuracy: 0.9451 - val_loss: 0.7364 - val_accuracy: 0.8437 - 272s/epoch - 2s/step
# Epoch 49/200
# 129/129 - 273s - loss: 0.1494 - accuracy: 0.9550 - val_loss: 0.6279 - val_accuracy: 0.8669 - 273s/epoch - 2s/step
# Epoch 50/200
# 129/129 - 274s - loss: 0.0941 - accuracy: 0.9706 - val_loss: 0.6839 - val_accuracy: 0.8692 - 274s/epoch - 2s/step
# Epoch 51/200
# 129/129 - 274s - loss: 0.0973 - accuracy: 0.9707 - val_loss: 0.7309 - val_accuracy: 0.8630 - 274s/epoch - 2s/step
# Epoch 52/200
# 129/129 - 276s - loss: 0.1457 - accuracy: 0.9536 - val_loss: 0.8236 - val_accuracy: 0.8465 - 276s/epoch - 2s/step
# Epoch 53/200
# 129/129 - 275s - loss: 0.1664 - accuracy: 0.9483 - val_loss: 0.7346 - val_accuracy: 0.8550 - 275s/epoch - 2s/step
# Epoch 54/200
# 129/129 - 277s - loss: 0.1628 - accuracy: 0.9522 - val_loss: 0.8582 - val_accuracy: 0.8290 - 277s/epoch - 2s/step
# Epoch 55/200
# 129/129 - 276s - loss: 0.1671 - accuracy: 0.9515 - val_loss: 0.6355 - val_accuracy: 0.8720 - 276s/epoch - 2s/step
# Epoch 56/200
# 129/129 - 275s - loss: 0.1001 - accuracy: 0.9690 - val_loss: 0.6594 - val_accuracy: 0.8692 - 275s/epoch - 2s/step
# Epoch 57/200
# 129/129 - 274s - loss: 0.1294 - accuracy: 0.9618 - val_loss: 0.7188 - val_accuracy: 0.8505 - 274s/epoch - 2s/step
# Epoch 58/200
# 129/129 - 278s - loss: 0.1462 - accuracy: 0.9569 - val_loss: 0.6240 - val_accuracy: 0.8686 - 278s/epoch - 2s/step
# Epoch 59/200
# 129/129 - 277s - loss: 0.0941 - accuracy: 0.9721 - val_loss: 0.6896 - val_accuracy: 0.8664 - 277s/epoch - 2s/step
# Epoch 60/200
# 129/129 - 278s - loss: 0.0990 - accuracy: 0.9700 - val_loss: 0.6393 - val_accuracy: 0.8749 - 278s/epoch - 2s/step
# Epoch 61/200
# 129/129 - 277s - loss: 0.0733 - accuracy: 0.9777 - val_loss: 0.7079 - val_accuracy: 0.8783 - 277s/epoch - 2s/step
# Epoch 62/200
# 129/129 - 273s - loss: 0.0734 - accuracy: 0.9778 - val_loss: 0.7493 - val_accuracy: 0.8703 - 273s/epoch - 2s/step
# Epoch 63/200
# 129/129 - 277s - loss: 0.1132 - accuracy: 0.9687 - val_loss: 0.7253 - val_accuracy: 0.8567 - 277s/epoch - 2s/step
# Epoch 64/200
# 129/129 - 279s - loss: 0.1092 - accuracy: 0.9677 - val_loss: 0.7126 - val_accuracy: 0.8669 - 279s/epoch - 2s/step
# Epoch 65/200
# 129/129 - 279s - loss: 0.1078 - accuracy: 0.9677 - val_loss: 0.6658 - val_accuracy: 0.8709 - 279s/epoch - 2s/step
# Epoch 66/200
# 129/129 - 282s - loss: 0.0903 - accuracy: 0.9721 - val_loss: 0.7343 - val_accuracy: 0.8618 - 282s/epoch - 2s/step
# Epoch 67/200
# 129/129 - 301s - loss: 0.0896 - accuracy: 0.9716 - val_loss: 0.7176 - val_accuracy: 0.8669 - 301s/epoch - 2s/step
# Epoch 68/200
# 129/129 - 305s - loss: 0.0983 - accuracy: 0.9695 - val_loss: 0.6362 - val_accuracy: 0.8783 - 305s/epoch - 2s/step
# Epoch 69/200
# 129/129 - 291s - loss: 0.0910 - accuracy: 0.9728 - val_loss: 0.7124 - val_accuracy: 0.8709 - 291s/epoch - 2s/step
# Epoch 70/200
# 129/129 - 276s - loss: 0.0959 - accuracy: 0.9707 - val_loss: 0.6690 - val_accuracy: 0.8743 - 276s/epoch - 2s/step
# Epoch 71/200
# 129/129 - 291s - loss: 0.0672 - accuracy: 0.9774 - val_loss: 0.6659 - val_accuracy: 0.8783 - 291s/epoch - 2s/step
# Epoch 72/200
# 129/129 - 279s - loss: 0.0629 - accuracy: 0.9805 - val_loss: 0.7341 - val_accuracy: 0.8743 - 279s/epoch - 2s/step
# Epoch 73/200
# 129/129 - 277s - loss: 0.1473 - accuracy: 0.9586 - val_loss: 0.8145 - val_accuracy: 0.8494 - 277s/epoch - 2s/step
# Epoch 74/200
# 129/129 - 280s - loss: 0.1401 - accuracy: 0.9574 - val_loss: 0.6536 - val_accuracy: 0.8726 - 280s/epoch - 2s/step
# Epoch 75/200
# 129/129 - 287s - loss: 0.1161 - accuracy: 0.9658 - val_loss: 0.6895 - val_accuracy: 0.8720 - 287s/epoch - 2s/step
# Epoch 76/200
# 129/129 - 292s - loss: 0.0888 - accuracy: 0.9734 - val_loss: 0.7363 - val_accuracy: 0.8698 - 292s/epoch - 2s/step
# Epoch 77/200
# 129/129 - 276s - loss: 0.0730 - accuracy: 0.9774 - val_loss: 0.7627 - val_accuracy: 0.8709 - 276s/epoch - 2s/step
# Epoch 78/200
# 129/129 - 278s - loss: 0.0786 - accuracy: 0.9777 - val_loss: 0.7311 - val_accuracy: 0.8732 - 278s/epoch - 2s/step
# Epoch 79/200
# 129/129 - 280s - loss: 0.1466 - accuracy: 0.9561 - val_loss: 0.8072 - val_accuracy: 0.8426 - 280s/epoch - 2s/step
# Epoch 80/200
# 129/129 - 276s - loss: 0.1280 - accuracy: 0.9614 - val_loss: 0.6780 - val_accuracy: 0.8703 - 276s/epoch - 2s/step
# Epoch 81/200
# 129/129 - 276s - loss: 0.0660 - accuracy: 0.9818 - val_loss: 0.7288 - val_accuracy: 0.8732 - 276s/epoch - 2s/step
# Epoch 82/200
# 129/129 - 279s - loss: 0.0585 - accuracy: 0.9823 - val_loss: 0.7102 - val_accuracy: 0.8760 - 279s/epoch - 2s/step
# Epoch 83/200
# 129/129 - 283s - loss: 0.0735 - accuracy: 0.9774 - val_loss: 0.7298 - val_accuracy: 0.8732 - 283s/epoch - 2s/step
# Epoch 84/200
# 129/129 - 280s - loss: 0.0904 - accuracy: 0.9729 - val_loss: 0.7685 - val_accuracy: 0.8635 - 280s/epoch - 2s/step
# Epoch 85/200
# 129/129 - 280s - loss: 0.0791 - accuracy: 0.9760 - val_loss: 0.6769 - val_accuracy: 0.8788 - 280s/epoch - 2s/step
# Epoch 86/200
# 129/129 - 281s - loss: 0.0709 - accuracy: 0.9782 - val_loss: 0.7203 - val_accuracy: 0.8703 - 281s/epoch - 2s/step
# Epoch 87/200
# 129/129 - 286s - loss: 0.0874 - accuracy: 0.9738 - val_loss: 0.7337 - val_accuracy: 0.8754 - 286s/epoch - 2s/step
# Epoch 88/200
